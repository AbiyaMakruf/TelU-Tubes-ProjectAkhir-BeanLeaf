# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import KFold
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import time
from datetime import datetime
import random
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input as efficientnetv2_preprocess

from tensorflow.keras.applications import (
    MobileNetV3Small,
    MobileNetV3Large,
    EfficientNetV2B0,
    EfficientNetV2B1,
    EfficientNetV2B2,
    EfficientNetV2B3,
    EfficientNetV2S,
    EfficientNetV2M,
    EfficientNetV2L
)

from efficientNet.efficientnet_v2_modifikasi import (
    EfficientNetV2B0Modifikasi,
    EfficientNetV2B1Modifikasi,
    EfficientNetV2B2Modifikasi,
    EfficientNetV2B3Modifikasi,
)
# Out:
# 2024-12-25 14:21:01.971224: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1735111262.013732   29226 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1735111262.026655   29226 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-25 14:21:02.196132: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Hyperparameter settings
batch_size = 32
epochs_size = 30
optimizer = "Adam"
dropout_rate = 0.2
learning_rate = 0.001
trainable_percentage = 0.3
trainable_percentage_modifikasi = 1

# Dataset directories
dataset_path = "datasets/"
train_dir = os.path.join(dataset_path, "training")
val_dir = os.path.join(dataset_path, "validation")
test_dir = os.path.join(dataset_path, "testing")

# Save paths
save_model_path = "results/best_model/kFold/"
result_csv_path = "results/csv/kFold/"
image_path = "results/images/kFold/"

input_shapes = {
    "MobileNetV3Small": (224, 224),
    "MobileNetV3Large": (224, 224),
    "EfficientNetV2B0": (224, 224),
    "EfficientNetV2B1": (240, 240),
    "EfficientNetV2B2": (260, 260),
    "EfficientNetV2B3": (300, 300),
    "EfficientNetV2B0Modifikasi": (224, 224),
    "EfficientNetV2B1Modifikasi": (240, 240),
    "EfficientNetV2B2Modifikasi": (260, 260),
    "EfficientNetV2B3Modifikasi": (300, 300),
}

# Random seed
random.seed(42)

# Select model
selected_model = "EfficientNetV2B0"  # Ganti model sesuai kebutuhan
img_height, img_width = input_shapes[selected_model]

def augmentation_generator_ENV2(img_height, img_width):
    train_datagen = ImageDataGenerator(
        preprocessing_function=efficientnetv2_preprocess,
        rotation_range=30,
        width_shift_range=0.3,
        height_shift_range=0.3,
        shear_range=0.3,
        zoom_range=0.3,
        horizontal_flip=True,
        fill_mode='nearest'
    )
    val_test_datagen = ImageDataGenerator(preprocessing_function=efficientnetv2_preprocess)
    return train_datagen, val_test_datagen

def prepare_dataset(train_dir):
    """Membuat daftar semua file dan label di direktori pelatihan."""
    classes = os.listdir(train_dir)
    filepaths = []
    labels = []

    for label, cls in enumerate(classes):
        cls_path = os.path.join(train_dir, cls)
        for fname in os.listdir(cls_path):
            filepaths.append(os.path.join(cls_path, fname))
            labels.append(label)

    return np.array(filepaths), np.array(labels)

def build_model(base_model, num_classes, dropout_rate):
    """Membangun model dengan arsitektur kustom."""
    return models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(dropout_rate),
        layers.Dense(128, activation='relu'),
        layers.Dropout(dropout_rate),
        layers.Dense(num_classes, activation='softmax')
    ])

def compile_model(model, learning_rate):
    """Mengompilasi model dengan optimizer dan loss function."""
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

def calculate_mean_std(results):
    """Menghitung mean dan std dari hasil fold."""
    mean_accuracy = np.mean(results['accuracy'])
    std_accuracy = np.std(results['accuracy'])
    mean_loss = np.mean(results['loss'])
    std_loss = np.std(results['loss'])
    return {
        'mean_accuracy': mean_accuracy,
        'std_accuracy': std_accuracy,
        'mean_loss': mean_loss,
        'std_loss': std_loss
    }

filepaths, labels = prepare_dataset(train_dir)

# Membagi dataset menggunakan KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)
results = {'fold': [], 'accuracy': [], 'loss': []}

for fold, (train_index, val_index) in enumerate(kf.split(filepaths)):
    print(f"Fold {fold + 1}")

    train_files, val_files = filepaths[train_index], filepaths[val_index]
    train_labels, val_labels = labels[train_index].astype(str), labels[val_index].astype(str)

    # Data augmentation
    train_datagen, val_test_datagen = augmentation_generator_ENV2(img_height, img_width)

    train_generator = train_datagen.flow_from_dataframe(
        dataframe=pd.DataFrame({'filename': train_files, 'class': train_labels}),
        x_col='filename',
        y_col='class',
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    val_generator = val_test_datagen.flow_from_dataframe(
        dataframe=pd.DataFrame({'filename': val_files, 'class': val_labels}),
        x_col='filename',
        y_col='class',
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False
    )

    # Load Base Model
    base_model = layers.Input(shape=(img_height, img_width, 3))

    # Build and Compile Model
    model = build_model(base_model, len(train_generator.class_indices), dropout_rate)
    compile_model(model, learning_rate)

    # Train Model
    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=epochs_size
    )

    # Evaluate Model
    eval_result = model.evaluate(val_generator)
    results['fold'].append(fold + 1)
    results['accuracy'].append(eval_result[1])
    results['loss'].append(eval_result[0])

# Calculate Mean and Std
metrics = calculate_mean_std(results)
print("Mean Accuracy:", metrics['mean_accuracy'])
print("Std Accuracy:", metrics['std_accuracy'])
print("Mean Loss:", metrics['mean_loss'])
print("Std Loss:", metrics['std_loss'])

# Save results to CSV
results_df = pd.DataFrame(results)
results_df['mean_accuracy'] = metrics['mean_accuracy']
results_df['std_accuracy'] = metrics['std_accuracy']
results_df['mean_loss'] = metrics['mean_loss']
results_df['std_loss'] = metrics['std_loss']
results_df.to_csv(os.path.join(result_csv_path, 'kfold_results.csv'), index=False)
# Out:
# Fold 1
# Found 745 validated image filenames belonging to 3 classes.
# Found 187 validated image filenames belonging to 3 classes.
# I0000 00:00:1735111608.600521   29226 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4080 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# /home/abiyamf/miniconda3/envs/projectAI/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1735111614.808639   29423 service.cc:148] XLA service 0x7fdbfc003da0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1735111614.808788   29423 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce GTX 1660 Ti, Compute Capability 7.5
# 2024-12-25 14:26:54.851306: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1735111615.016862   29423 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  1/24 ━━━━━━━━━━━━━━━━━━━━ 1:13 3s/step - accuracy: 0.1875 - loss: 16.1020
# I0000 00:00:1735111616.742797   29423 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 13s 409ms/step - accuracy: 0.3338 - loss: 9.1868 - val_accuracy: 0.4599 - val_loss: 1.6116
# Epoch 2/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 296ms/step - accuracy: 0.3848 - loss: 4.4858 - val_accuracy: 0.4706 - val_loss: 1.7034
# Epoch 3/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 300ms/step - accuracy: 0.4449 - loss: 2.7708 - val_accuracy: 0.3743 - val_loss: 1.3198
# Epoch 4/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - accuracy: 0.3706 - loss: 2.0069 - val_accuracy: 0.4011 - val_loss: 1.0769
# Epoch 5/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - accuracy: 0.4209 - loss: 1.3605 - val_accuracy: 0.4545 - val_loss: 1.0670
# Epoch 6/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 299ms/step - accuracy: 0.4372 - loss: 1.2229 - val_accuracy: 0.4332 - val_loss: 1.0566
# Epoch 7/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 291ms/step - accuracy: 0.3810 - loss: 1.1661 - val_accuracy: 0.4813 - val_loss: 1.0562
# Epoch 8/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - accuracy: 0.4309 - loss: 1.1116 - val_accuracy: 0.4973 - val_loss: 1.0675
# Epoch 9/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - accuracy: 0.4123 - loss: 1.0895 - val_accuracy: 0.4973 - val_loss: 1.0715
# Epoch 10/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 317ms/step - accuracy: 0.4665 - loss: 1.0417 - val_accuracy: 0.5401 - val_loss: 1.0414
# Epoch 11/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 322ms/step - accuracy: 0.4120 - loss: 1.0904 - val_accuracy: 0.5294 - val_loss: 1.0499
# Epoch 12/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 300ms/step - accuracy: 0.4686 - loss: 1.0644 - val_accuracy: 0.5080 - val_loss: 1.0293
# Epoch 13/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 301ms/step - accuracy: 0.4862 - loss: 1.0470 - val_accuracy: 0.5241 - val_loss: 0.9964
# Epoch 14/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 300ms/step - accuracy: 0.5088 - loss: 1.0366 - val_accuracy: 0.4813 - val_loss: 1.0018
# Epoch 15/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - accuracy: 0.4744 - loss: 1.0266 - val_accuracy: 0.5241 - val_loss: 1.0087
# Epoch 16/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 296ms/step - accuracy: 0.5078 - loss: 1.0153 - val_accuracy: 0.5615 - val_loss: 1.0079
# Epoch 17/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 302ms/step - accuracy: 0.4760 - loss: 1.0463 - val_accuracy: 0.5348 - val_loss: 1.0044
# Epoch 18/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - accuracy: 0.4919 - loss: 1.0187 - val_accuracy: 0.5508 - val_loss: 0.9745
# Epoch 19/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - accuracy: 0.4499 - loss: 1.0356 - val_accuracy: 0.5294 - val_loss: 0.9818
# Epoch 20/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 285ms/step - accuracy: 0.4719 - loss: 1.0135 - val_accuracy: 0.4973 - val_loss: 0.9922
# Epoch 21/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 295ms/step - accuracy: 0.4897 - loss: 1.0121 - val_accuracy: 0.5508 - val_loss: 0.9714
# Epoch 22/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - accuracy: 0.5045 - loss: 0.9975 - val_accuracy: 0.5401 - val_loss: 0.9719
# Epoch 23/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 314ms/step - accuracy: 0.5151 - loss: 1.0069 - val_accuracy: 0.5508 - val_loss: 0.9642
# Epoch 24/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - accuracy: 0.5035 - loss: 1.0075 - val_accuracy: 0.5561 - val_loss: 0.9575
# Epoch 25/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 293ms/step - accuracy: 0.4886 - loss: 1.0322 - val_accuracy: 0.5401 - val_loss: 0.9684
# Epoch 26/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 344ms/step - accuracy: 0.4619 - loss: 1.0484 - val_accuracy: 0.5294 - val_loss: 0.9707
# Epoch 27/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 301ms/step - accuracy: 0.5172 - loss: 1.0053 - val_accuracy: 0.5401 - val_loss: 0.9554
# Epoch 28/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 298ms/step - accuracy: 0.5259 - loss: 0.9769 - val_accuracy: 0.5187 - val_loss: 0.9710
# Epoch 29/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 291ms/step - accuracy: 0.4992 - loss: 1.0088 - val_accuracy: 0.5080 - val_loss: 0.9837
# Epoch 30/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 304ms/step - accuracy: 0.5327 - loss: 0.9740 - val_accuracy: 0.5134 - val_loss: 0.9668
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.3676 - loss: 1.0586
# Fold 2
# Found 745 validated image filenames belonging to 3 classes.
# Found 187 validated image filenames belonging to 3 classes.
# /home/abiyamf/miniconda3/envs/projectAI/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 335ms/step - accuracy: 0.3276 - loss: 9.8237 - val_accuracy: 0.4492 - val_loss: 1.8843
# Epoch 2/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 293ms/step - accuracy: 0.3607 - loss: 4.4650 - val_accuracy: 0.4920 - val_loss: 1.2972
# Epoch 3/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 286ms/step - accuracy: 0.3763 - loss: 2.8901 - val_accuracy: 0.4439 - val_loss: 1.0621
# Epoch 4/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - accuracy: 0.3998 - loss: 1.7451 - val_accuracy: 0.6043 - val_loss: 0.9472
# Epoch 5/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 286ms/step - accuracy: 0.4360 - loss: 1.3933 - val_accuracy: 0.4599 - val_loss: 0.9783
# Epoch 6/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - accuracy: 0.4187 - loss: 1.1904 - val_accuracy: 0.5187 - val_loss: 0.9998
# Epoch 7/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - accuracy: 0.4216 - loss: 1.1307 - val_accuracy: 0.5348 - val_loss: 1.0170
# Epoch 8/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - accuracy: 0.4494 - loss: 1.0858 - val_accuracy: 0.5615 - val_loss: 1.0178
# Epoch 9/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - accuracy: 0.4323 - loss: 1.0793 - val_accuracy: 0.5134 - val_loss: 1.0061
# Epoch 10/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 284ms/step - accuracy: 0.4532 - loss: 1.0534 - val_accuracy: 0.4545 - val_loss: 1.0167
# Epoch 11/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - accuracy: 0.4464 - loss: 1.0816 - val_accuracy: 0.5027 - val_loss: 1.0164
# Epoch 12/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - accuracy: 0.4796 - loss: 1.0570 - val_accuracy: 0.5134 - val_loss: 0.9929
# Epoch 13/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - accuracy: 0.4882 - loss: 1.0255 - val_accuracy: 0.4759 - val_loss: 0.9918
# Epoch 14/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 295ms/step - accuracy: 0.4484 - loss: 1.0541 - val_accuracy: 0.5241 - val_loss: 0.9897
# Epoch 15/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - accuracy: 0.4671 - loss: 1.0211 - val_accuracy: 0.5455 - val_loss: 0.9487
# Epoch 16/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 299ms/step - accuracy: 0.4870 - loss: 1.0138 - val_accuracy: 0.6096 - val_loss: 0.9600
# Epoch 17/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 344ms/step - accuracy: 0.4874 - loss: 1.0228 - val_accuracy: 0.5615 - val_loss: 0.9606
# Epoch 18/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 332ms/step - accuracy: 0.5255 - loss: 1.0009 - val_accuracy: 0.5775 - val_loss: 0.9575
# Epoch 19/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 319ms/step - accuracy: 0.5098 - loss: 1.0036 - val_accuracy: 0.5936 - val_loss: 0.9373
# Epoch 20/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 327ms/step - accuracy: 0.4472 - loss: 1.0343 - val_accuracy: 0.5401 - val_loss: 0.9539
# Epoch 21/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 343ms/step - accuracy: 0.4719 - loss: 1.0034 - val_accuracy: 0.6043 - val_loss: 0.9296
# Epoch 22/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 329ms/step - accuracy: 0.4945 - loss: 1.0054 - val_accuracy: 0.6203 - val_loss: 0.9432
# Epoch 23/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 328ms/step - accuracy: 0.4999 - loss: 0.9923 - val_accuracy: 0.5989 - val_loss: 0.9413
# Epoch 24/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.4798 - loss: 1.0473 - val_accuracy: 0.5882 - val_loss: 0.9428
# Epoch 25/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 337ms/step - accuracy: 0.5182 - loss: 0.9802 - val_accuracy: 0.5829 - val_loss: 0.9220
# Epoch 26/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - accuracy: 0.4716 - loss: 1.0092 - val_accuracy: 0.5401 - val_loss: 0.9557
# Epoch 27/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 324ms/step - accuracy: 0.5091 - loss: 0.9887 - val_accuracy: 0.5561 - val_loss: 0.9458
# Epoch 28/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 314ms/step - accuracy: 0.4882 - loss: 1.0062 - val_accuracy: 0.5882 - val_loss: 0.9277
# Epoch 29/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 315ms/step - accuracy: 0.4613 - loss: 1.0261 - val_accuracy: 0.6150 - val_loss: 0.9309
# Epoch 30/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 365ms/step - accuracy: 0.4829 - loss: 0.9985 - val_accuracy: 0.5882 - val_loss: 0.9092
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.5740 - loss: 0.9007
# Fold 3
# Found 746 validated image filenames belonging to 3 classes.
# Found 186 validated image filenames belonging to 3 classes.
# /home/abiyamf/miniconda3/envs/projectAI/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 13s 395ms/step - accuracy: 0.3309 - loss: 11.3595 - val_accuracy: 0.5376 - val_loss: 1.0531
# Epoch 2/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 351ms/step - accuracy: 0.3777 - loss: 5.7546 - val_accuracy: 0.4462 - val_loss: 2.1540
# Epoch 3/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 326ms/step - accuracy: 0.3663 - loss: 3.7486 - val_accuracy: 0.5108 - val_loss: 1.0055
# Epoch 4/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - accuracy: 0.4045 - loss: 2.0403 - val_accuracy: 0.4086 - val_loss: 1.0316
# Epoch 5/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 303ms/step - accuracy: 0.3712 - loss: 1.4968 - val_accuracy: 0.3978 - val_loss: 1.0782
# Epoch 6/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - accuracy: 0.3736 - loss: 1.2301 - val_accuracy: 0.4301 - val_loss: 1.0884
# Epoch 7/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 305ms/step - accuracy: 0.3890 - loss: 1.1919 - val_accuracy: 0.4409 - val_loss: 1.0805
# Epoch 8/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 293ms/step - accuracy: 0.4160 - loss: 1.1209 - val_accuracy: 0.3978 - val_loss: 1.0883
# Epoch 9/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 301ms/step - accuracy: 0.4516 - loss: 1.1279 - val_accuracy: 0.4086 - val_loss: 1.0822
# Epoch 10/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 311ms/step - accuracy: 0.4084 - loss: 1.0898 - val_accuracy: 0.3871 - val_loss: 1.0761
# Epoch 11/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 314ms/step - accuracy: 0.4155 - loss: 1.1180 - val_accuracy: 0.4677 - val_loss: 1.0335
# Epoch 12/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 305ms/step - accuracy: 0.4262 - loss: 1.0678 - val_accuracy: 0.3763 - val_loss: 1.0778
# Epoch 13/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 299ms/step - accuracy: 0.4206 - loss: 1.0968 - val_accuracy: 0.4301 - val_loss: 1.0528
# Epoch 14/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - accuracy: 0.4510 - loss: 1.0462 - val_accuracy: 0.4462 - val_loss: 1.0274
# Epoch 15/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - accuracy: 0.4800 - loss: 1.0450 - val_accuracy: 0.4839 - val_loss: 0.9920
# Epoch 16/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 322ms/step - accuracy: 0.4555 - loss: 1.0043 - val_accuracy: 0.5054 - val_loss: 0.9765
# Epoch 17/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - accuracy: 0.4913 - loss: 1.0241 - val_accuracy: 0.4409 - val_loss: 1.0066
# Epoch 18/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 349ms/step - accuracy: 0.4698 - loss: 1.0213 - val_accuracy: 0.4624 - val_loss: 0.9959
# Epoch 19/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 303ms/step - accuracy: 0.4515 - loss: 1.0302 - val_accuracy: 0.5108 - val_loss: 0.9660
# Epoch 20/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 326ms/step - accuracy: 0.4401 - loss: 1.0312 - val_accuracy: 0.4731 - val_loss: 0.9847
# Epoch 21/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - accuracy: 0.4479 - loss: 1.0423 - val_accuracy: 0.4946 - val_loss: 0.9723
# Epoch 22/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 304ms/step - accuracy: 0.5145 - loss: 0.9935 - val_accuracy: 0.4785 - val_loss: 0.9730
# Epoch 23/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 296ms/step - accuracy: 0.4967 - loss: 0.9942 - val_accuracy: 0.5054 - val_loss: 0.9595
# Epoch 24/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 313ms/step - accuracy: 0.4920 - loss: 1.0081 - val_accuracy: 0.4839 - val_loss: 0.9657
# Epoch 25/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - accuracy: 0.4657 - loss: 0.9974 - val_accuracy: 0.4677 - val_loss: 0.9813
# Epoch 26/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 326ms/step - accuracy: 0.5388 - loss: 0.9796 - val_accuracy: 0.5108 - val_loss: 0.9410
# Epoch 27/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 301ms/step - accuracy: 0.4793 - loss: 1.0014 - val_accuracy: 0.4892 - val_loss: 0.9481
# Epoch 28/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 302ms/step - accuracy: 0.4824 - loss: 0.9952 - val_accuracy: 0.5054 - val_loss: 0.9373
# Epoch 29/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 308ms/step - accuracy: 0.4572 - loss: 0.9960 - val_accuracy: 0.5000 - val_loss: 0.9561
# Epoch 30/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 321ms/step - accuracy: 0.5156 - loss: 0.9629 - val_accuracy: 0.5269 - val_loss: 0.9325
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.4653 - loss: 0.9512
# Fold 4
# Found 746 validated image filenames belonging to 3 classes.
# Found 186 validated image filenames belonging to 3 classes.
# /home/abiyamf/miniconda3/envs/projectAI/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 349ms/step - accuracy: 0.3680 - loss: 8.9192 - val_accuracy: 0.6237 - val_loss: 1.7614
# Epoch 2/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 302ms/step - accuracy: 0.3666 - loss: 4.9072 - val_accuracy: 0.5968 - val_loss: 1.3836
# Epoch 3/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 309ms/step - accuracy: 0.4535 - loss: 2.4014 - val_accuracy: 0.5323 - val_loss: 1.0253
# Epoch 4/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - accuracy: 0.4346 - loss: 1.6500 - val_accuracy: 0.4247 - val_loss: 1.0537
# Epoch 5/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 315ms/step - accuracy: 0.4225 - loss: 1.2456 - val_accuracy: 0.3280 - val_loss: 1.1269
# Epoch 6/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 308ms/step - accuracy: 0.4152 - loss: 1.1680 - val_accuracy: 0.6129 - val_loss: 1.0446
# Epoch 7/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - accuracy: 0.4575 - loss: 1.1274 - val_accuracy: 0.6075 - val_loss: 1.0277
# Epoch 8/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 308ms/step - accuracy: 0.4462 - loss: 1.0408 - val_accuracy: 0.4624 - val_loss: 1.0322
# Epoch 9/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 337ms/step - accuracy: 0.4394 - loss: 1.0698 - val_accuracy: 0.5430 - val_loss: 1.0307
# Epoch 10/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - accuracy: 0.3997 - loss: 1.0950 - val_accuracy: 0.6129 - val_loss: 0.9985
# Epoch 11/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 319ms/step - accuracy: 0.4482 - loss: 1.0497 - val_accuracy: 0.5591 - val_loss: 0.9840
# Epoch 12/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 306ms/step - accuracy: 0.4550 - loss: 1.0207 - val_accuracy: 0.6022 - val_loss: 0.9851
# Epoch 13/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 320ms/step - accuracy: 0.4422 - loss: 1.0617 - val_accuracy: 0.5914 - val_loss: 1.0004
# Epoch 14/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 312ms/step - accuracy: 0.4709 - loss: 1.0230 - val_accuracy: 0.5753 - val_loss: 0.9967
# Epoch 15/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 321ms/step - accuracy: 0.4348 - loss: 1.0046 - val_accuracy: 0.6183 - val_loss: 0.9525
# Epoch 16/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 311ms/step - accuracy: 0.4443 - loss: 1.0120 - val_accuracy: 0.5914 - val_loss: 0.9536
# Epoch 17/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.4861 - loss: 1.0151 - val_accuracy: 0.6129 - val_loss: 0.9802
# Epoch 18/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - accuracy: 0.4939 - loss: 1.0136 - val_accuracy: 0.5591 - val_loss: 0.9873
# Epoch 19/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 468ms/step - accuracy: 0.4633 - loss: 1.0101 - val_accuracy: 0.5806 - val_loss: 0.9872
# Epoch 20/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 454ms/step - accuracy: 0.4540 - loss: 1.0041 - val_accuracy: 0.5968 - val_loss: 0.9486
# Epoch 21/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 335ms/step - accuracy: 0.4576 - loss: 1.0160 - val_accuracy: 0.6075 - val_loss: 0.9589
# Epoch 22/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.4745 - loss: 1.0226 - val_accuracy: 0.5806 - val_loss: 0.9856
# Epoch 23/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 311ms/step - accuracy: 0.4817 - loss: 0.9944 - val_accuracy: 0.6290 - val_loss: 0.9383
# Epoch 24/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 309ms/step - accuracy: 0.4929 - loss: 0.9748 - val_accuracy: 0.6022 - val_loss: 0.9414
# Epoch 25/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 310ms/step - accuracy: 0.5120 - loss: 1.0101 - val_accuracy: 0.5914 - val_loss: 0.9867
# Epoch 26/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 305ms/step - accuracy: 0.4544 - loss: 1.0269 - val_accuracy: 0.6183 - val_loss: 0.9499
# Epoch 27/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - accuracy: 0.4966 - loss: 1.0113 - val_accuracy: 0.6075 - val_loss: 0.9355
# Epoch 28/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - accuracy: 0.5032 - loss: 0.9909 - val_accuracy: 0.6022 - val_loss: 0.9392
# Epoch 29/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - accuracy: 0.5029 - loss: 0.9881 - val_accuracy: 0.5914 - val_loss: 0.9193
# Epoch 30/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 320ms/step - accuracy: 0.4435 - loss: 1.0488 - val_accuracy: 0.5914 - val_loss: 0.9841
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.5702 - loss: 0.9533
# Fold 5
# Found 746 validated image filenames belonging to 3 classes.
# Found 186 validated image filenames belonging to 3 classes.
# /home/abiyamf/miniconda3/envs/projectAI/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 353ms/step - accuracy: 0.3762 - loss: 13.6821 - val_accuracy: 0.3172 - val_loss: 2.7883
# Epoch 2/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 9s 381ms/step - accuracy: 0.3881 - loss: 5.0298 - val_accuracy: 0.4785 - val_loss: 1.2642
# Epoch 3/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 343ms/step - accuracy: 0.4213 - loss: 3.0113 - val_accuracy: 0.3333 - val_loss: 1.2111
# Epoch 4/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 307ms/step - accuracy: 0.4176 - loss: 1.9688 - val_accuracy: 0.4624 - val_loss: 1.0210
# Epoch 5/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 319ms/step - accuracy: 0.4039 - loss: 1.3986 - val_accuracy: 0.5161 - val_loss: 1.0483
# Epoch 6/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - accuracy: 0.4436 - loss: 1.1154 - val_accuracy: 0.4301 - val_loss: 1.0563
# Epoch 7/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - accuracy: 0.3961 - loss: 1.1915 - val_accuracy: 0.4892 - val_loss: 1.0539
# Epoch 8/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 348ms/step - accuracy: 0.4321 - loss: 1.1553 - val_accuracy: 0.4785 - val_loss: 1.0468
# Epoch 9/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 350ms/step - accuracy: 0.4597 - loss: 1.0961 - val_accuracy: 0.5269 - val_loss: 1.0225
# Epoch 10/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 8s 336ms/step - accuracy: 0.4299 - loss: 1.0902 - val_accuracy: 0.4624 - val_loss: 1.0264
# Epoch 11/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 299ms/step - accuracy: 0.4639 - loss: 1.0445 - val_accuracy: 0.4785 - val_loss: 1.0196
# Epoch 12/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 293ms/step - accuracy: 0.5101 - loss: 1.0210 - val_accuracy: 0.5538 - val_loss: 1.0093
# Epoch 13/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 303ms/step - accuracy: 0.4193 - loss: 1.0828 - val_accuracy: 0.4785 - val_loss: 1.0386
# Epoch 14/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 304ms/step - accuracy: 0.4041 - loss: 1.0870 - val_accuracy: 0.5430 - val_loss: 1.0126
# Epoch 15/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 293ms/step - accuracy: 0.4563 - loss: 1.0705 - val_accuracy: 0.5376 - val_loss: 1.0025
# Epoch 16/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 295ms/step - accuracy: 0.4674 - loss: 1.0259 - val_accuracy: 0.4731 - val_loss: 1.0069
# Epoch 17/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 298ms/step - accuracy: 0.4574 - loss: 1.0175 - val_accuracy: 0.5376 - val_loss: 1.0060
# Epoch 18/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 303ms/step - accuracy: 0.4902 - loss: 0.9853 - val_accuracy: 0.4892 - val_loss: 0.9980
# Epoch 19/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 308ms/step - accuracy: 0.4980 - loss: 0.9972 - val_accuracy: 0.5269 - val_loss: 0.9971
# Epoch 20/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - accuracy: 0.4963 - loss: 1.0165 - val_accuracy: 0.5538 - val_loss: 1.0023
# Epoch 21/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - accuracy: 0.4822 - loss: 1.0121 - val_accuracy: 0.5215 - val_loss: 0.9979
# Epoch 22/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - accuracy: 0.5026 - loss: 1.0237 - val_accuracy: 0.5323 - val_loss: 0.9807
# Epoch 23/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 296ms/step - accuracy: 0.4823 - loss: 0.9952 - val_accuracy: 0.5591 - val_loss: 0.9752
# Epoch 24/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - accuracy: 0.4879 - loss: 1.0071 - val_accuracy: 0.5484 - val_loss: 0.9756
# Epoch 25/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 295ms/step - accuracy: 0.4973 - loss: 1.0060 - val_accuracy: 0.5323 - val_loss: 0.9837
# Epoch 26/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - accuracy: 0.4899 - loss: 1.0087 - val_accuracy: 0.5538 - val_loss: 0.9723
# Epoch 27/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 298ms/step - accuracy: 0.4920 - loss: 1.0145 - val_accuracy: 0.5430 - val_loss: 0.9754
# Epoch 28/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 297ms/step - accuracy: 0.5300 - loss: 1.0068 - val_accuracy: 0.5376 - val_loss: 0.9851
# Epoch 29/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 303ms/step - accuracy: 0.5247 - loss: 0.9608 - val_accuracy: 0.5645 - val_loss: 0.9762
# Epoch 30/30
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - accuracy: 0.5256 - loss: 0.9567 - val_accuracy: 0.5108 - val_loss: 0.9835
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.3720 - loss: 1.0710
# Mean Accuracy: 0.5461272954940796
# Std Accuracy: 0.03610365953988038
# Mean Loss: 0.9552020907402039
# Std Loss: 0.02966924481731217
